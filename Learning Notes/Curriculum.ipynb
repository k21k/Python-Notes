# %% [markdown]
# # Course content
#
#     1- Python basics
#         - Lists                                                Done
#         - Functions/Methods                                    Done
#         - Lambda expressions                                   Done
#         - Built-in functions                                   Done
#         - Dictionaries                                         Done
#         - if else statements                                   Done
#         - Loops                                                Done
#         - File handling                                        Done
#         - Exception handling                                   Done
#         - Regular Expression                                   Done
#         - Modules and Packages                                 Done
#         - Game project                                         Done
#
#     2- Object Oriented Programming using Python
#         - Classes                                              Done
#         - Objects                                              Done
#         - Methods                                              Done
#         - The __init__() Function (Contructor)                 Done
#         - Inheritence                                          Done
#         - Game project                                         Done
#         - Composition                                          Done
#
#     ------------------ Data Pre-processing ------------------------
#
#     3- Numpy for data analysis
#         - Introduction to numpy                                Done
#         - Numpy Arrays                                         Done
#         - Numpy Array Indexing                                 Done
#         - Numpy Operations                                     Done
#         - Numpy Exercise and Solutions                         Done
#
#     4- Pandas for data analysis
#         - Introduction to Pandas                               Done
#         - Series                                               Done
#         - DataFrames                                           Done
#         - Dealing with missing data                            Done
#         - GroupBy                                              Done
#         - Merging, joining and concatinating                   Done
#         - Operations                                           Done
#         - Data input and Output                                Done
#         - Pandas Exercise and Solutions                        Done
#         - Label encoding                                       Done
#         - Feature selection                                    Done
#         - Splitting the dataset                                Done
#
#
#      ------------------ Data Visualization ------------------------
#      ------------------ Exploratory Data Analysis -----------------
#
#     5- Matplotlib for Data Visualization
#         - Introduction to Matplotlib                           Done
#         - Different kinds of plotting                          Done
#             - Plots and Subplots                               Done
#             - Scatter Plots, Box plots                         Done
#         - Matplotlib Exercise and Solutions                    Done
#         - Advanced Matplotlib concepts                         Done
#
# ***---------- May 26th to June 01-----------------***
#
#     6- Seaborn for Data Visualization
#         - Introduction to Seaborn
#         - Distribution plots
#         - Categorical Plots
#         - Matrix Plots
#         - Grids
#         - Regression Plots
#         - Style and Color
#         - Seaborn Exercise and solutions
# ***-----------------------------------------------***
#
# ***---------- June 01 to June 08------------------***
#
#     7- Pandas Built-in Data Visualization
#         - Exercises and solutions
#
#     8- Plotly and cufflinks
#         - Geographical plotting
#         - Choropleth Maps
#         - Choropleth Exercises and solutions
#
#     9- Data Capstone Projects
#         - In this section, I'll give you a project as a test.
#
# ***-----------------------------------------------***
#
# **(1 Week)  June 08 - June 15:**
#
#     Introduction to Machine Learning,
#     Linear Regression,
#     Logistic Regression
# **(2 Weeks) June 15 - June 29:**
#
#     KNN,
#     Decision Trees,
#     Random Forests,
#     SVM
# **(1 Week)  June 29 - July 06:**
#
#     K-Means Clustering,
#     Recommender Systems,
#     Natural Language Processing
# **(3 Week)  July 06 - July 27:**
#
#     Big Data and Spark with Python,
#     Neural Networks,
#     Deep Learning,
#     Tensorflow
#
# ## Note:
# ***We'll try to cover every section by mid july. I've considered the maximum time.***

# %% [markdown]
# # Pricing and time each section will take
#
#         1-  Python Basics    :    2 weeks        100 USD   (50 x 2)
#         2-  OOP              :    1 week          50 USD
#         3-  Numpy            :    1 week          50 USD
#         4-  Pandas           :    1 week          50 USD
#         5-  Matplotlib       :    1 week          50 USD
#         6-  Seaborn          :    1 week          50 USD
#         7-  Pandas(Visuals)  :    1 week          50 USD
#         8-  Plotly/Cufflinks :    1 week          50 USD
#         9-  Capstone Project :    1 week          50 USD
#         10- Machine Learning :    4 weeks        240 USD   (60 x 4)
#                                                 ---------
#         Total Amount in USD  :                   740 USD   (14 weeks)
# ### Breaking down Machine Learning section:
#
#         Week 1-  Introduction to Machine Learning, Linear Regression, Logistic Regression
#         Week 2-  KNN, Decision Trees, Random Forests, SVM
#         Week 3-  K-Means Clustering, Recommender Systems, Natural Language Processing
#         Week 4-  Big Data and Spark with Python, Neural Networks and Deep Learning, Tensorflow

# %% [markdown]
# ### Note:
#     I have made the best possible curriculum you can have:
#     Things you'll get in each section:
#         1- Detailed Overview
#         2- Helping Materials (Notes, useful links)
#         3- Video Sessions (3/week)
#         4- Exercises
#         5- Exercise Solutions in the video sessions
#
#
#     Section 10:
#         Machine Learning - That are some advanced topics, and require more effort and time to build exercises, So I've asked 60 USD per week for it.
