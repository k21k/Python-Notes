# %% [markdown]
# # Ploting from csv

# %%
import pandas as pd
import matplotlib.pyplot as plt

aa = pd.read_csv(r'C:\Users\delchain_default\Documents\GitHub\Kaggle-DataSets\Apple Mobility Data\test.csv')
aa.head
# Out:
# <bound method NDFrame.head of      x     y
# 0   12  23.0
# 1   13  17.5
# 2   13  17.5
# 3   14  18.5
# 4   14  18.5
# 5   15  19.5
# 6   15  19.5
# 7   16  20.5
# 8   16  20.5
# 9   17  21.5
# 10  17  21.5
# 11  18  22.5
# 12  18  22.5
# 13  19  23.5
# 14  19  23.5
# 15  20  24.5
# 16  20  24.5
# 17  21  25.5
# 18  21  25.5
# 19  22  26.5
# 20  22  26.5
# 21  23  27.5
# 22  23  27.5
# 23  24  28.5>

# %%
aa.plot()

# this is not what i was looking for

# %%
x = aa['x']
y = aa['y']

fig, axes = plt.subplots(1,1, figsize = (9,5))

axes.plot(x, y)

# this is what i was looking for
