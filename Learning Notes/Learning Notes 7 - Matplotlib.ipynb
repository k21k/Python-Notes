# %% [markdown]
# # Learning Note 7 - Matplotlib

# %% [markdown]
# ## Intro

# %%
Isntall: conda install matplotlib

# %%
http://matplotlib.org/

# %%
To see plots in Jupyter Notebook: %matplotlib inline

# %% [markdown]
# Matplotlib is the "grandfather" library of data visualization with Python. It was created by John Hunter. He created it to try to replicate MatLab's (another programming language) plotting capabilities in Python. It is an excellent 2D and 3D graphics library for generating scientific figures.
#
# Some of the major Pros of Matplotlib are:
#
# * Generally easy to get started for simple plots
#
# * Support for custom labels and texts
#
# * Great control of every element in a figure
#
# * High-quality output in many formats
#
# * Very customizable in general

# %% [markdown]
# ## First Simple Matplotib Plotting

# %%
import matplotlib.pyplot as plt 

x = [1,2,3,4]     # x axis
y = [1,2,3,4]     # y axis

plt.plot(x,y)     # plotting the graph
plt.show()        #Displaying the figures

# %%
import numpy as np
import matplotlib.pyplot as plt

x =np.arange(0.0,6.0,0.01)
y = [x**2 for x in x]

plt.plot(x,y, color = 'red')  # plotting the graph 
plt.show()                    #Displaying the figures

# %%
import matplotlib.pyplot as plt
import numpy as np

x =np.arange(1,10)         # values from 1 to 10
y1 = x+2
y2 = x*6
y3 = x/5

plt.grid(True)
plt.xlabel("This is x-axis label")
plt.ylabel("This is y-axis label")
plt.title('Title name') 

plt.plot(x,y1, x,y2, x,y3) # plot the figure
plt.show()

# %% [markdown]
# ## Bar Chart

# %%
import matplotlib.pyplot as plt

plt.bar([1,2,3],[5,2,1],width=0.5,color="red")

plt.xlabel("This is x-axis label")
plt.ylabel("This is y-axis label")

plt.title("Simple Bar Chart")

plt.show()

# %%
For the bar chart below, 
You have to draw the values in x axis using the number of elements in the list that is length.

Therefore you will use the statement index = np.arange(len(student_name)) to find out the total number of values in the x -axis. 
It will  generate array of sequences number 

There are two list student_name and marks. In this case it will generate array [0,1,2,3]. 
It will decide the number of bars in the chart. 
In the same way, plt.xticks(index,student_name) will put the name of students on the x-axis.

# %%
import matplotlib.pyplot as plt
import numpy as np

student_name= [ "John","Sahil","Monica","Lara" ]
index = np.arange(len(student_name))
marks = [75,98,53,70]

plt.bar(index,marks)
plt.xticks(index,student_name)

plt.xlabel("Student Name")
plt.ylabel("Marks")
plt.title("Student Performance")

plt.show()

# %% [markdown]
# ## Pie Chart

# %%
import matplotlib.pyplot as plt

percentage = [60,30,10]
language= ["Python","Java","C++"]

plt.pie(percentage,labels=language)

plt.title("Simple Pie Chart")

plt.show()

# %% [markdown]
# ## Scatter Plotting

# %%
import matplotlib.pyplot as plt
import numpy as np

x= np.random.rand(100)
y=np.random.rand(100)

plt.scatter(x,y)

plt.title("Simple Scatter Plot")

plt.show()

# %% [markdown]
# ## Histogram Charts

# %%
import matplotlib.pyplot as plt
import numpy as np

x= np.random.rand(100)

plt.hist(x,10)

plt.title("Simple Histogram Chart")

plt.show()

# %% [markdown]
# ## Area Chart

# %%
import matplotlib.pyplot as plt
import numpy as np

x = [0. , 0.5, 1. , 1.5, 2. , 2.5, 3. , 3.5, 4. , 4.5, 5. ]
y = [0.  ,  0.25,  1.  ,  2.25,  4.  ,  6.25,  9.  , 12.25, 16.  , 20.25, 25.  ]

plt.fill_between(x,y)
plt.title("Simple Area Chart")

plt.show()

# %% [markdown]
# ## Other Features

# %% [markdown]
# ### Adding Text

# %%
import numpy as np
x= np.arange(0,2*np.pi,0.02) # values of x from 0 to 2pie

y=np.sin(x)
plt.plot(x,y)

plt.text(1.5,1,"Sin(90)=1")
plt.text(3.2,0,"Wooohooo")
plt.title("Add the text inside Figure")

plt.show()

# %% [markdown]
# ### Display

# %%
xticks([]), yticks([])                                    # to remove x and y ticks on axis
plt.plot(a,b, linestyle='--',color='red', marker='*')     # different styles

plt.xlabel("Set X Label")                                 # x axis title
plt.ylabel("Set Y Label")                                 # y axis title
plt.title('Set Title')                                    # title for the figure

# %%
# Possible line and marker styles
   -                solid line style
   --               dashed line style
   -.               dash-dot line style
   :                dotted line style
    
   .                point marker
   ,                pixel marker
   o                circle marker
   v                triangle_down marker
   ^                triangle_up marker
   <                triangle_left marker
   >                triangle_right marker
   1                tri_down marker
   2                tri_up marker
   3                tri_left marker
   4                tri_right marker
   s                square marker
   p                pentagon marker
   *                star marker
   h                hexagon1 marker
   H                hexagon2 marker
   +                plus marker
   x                x marker
   D                diamond marker
   d                thin_diamond marker
   |                vline marker
   _                hline marker

# %% [markdown]
# ### Colors

# %%
https://matplotlib.org/3.1.0/gallery/color/named_colors.html

# %% [markdown]
# ## Subplot & Multiple charts

# %%
https://matplotlib.org/3.2.0/api/_as_gen/matplotlib.pyplot.subplots.html

# %% [markdown]
# #### Method 1: subplot(1,1,1)

# %%
 There are two functions required for creating subplots.
- figure() 
- add_subplot(n_rows,n_coloumns,figureNumber)

# %%
The function figure.add_subplot(2,1,1) will return axes to the variable axis1. 
You can see the arguments for this function are 
- the number of rows that is 2, import matplotlib.pyplot as plt

figure= plt.figure()
figure.suptitle("Subplot Graph")

axis1 = figure.add_subplot(1,2,1)    # could be (121)
axis1.plot([1,2,3],[1,2,3])
axis1.set_title("First Plot")

axis2 = figure.add_subplot(1,2,2)    # could be (122)
axis2.plot([1,2,3],[3,2,1])
axis2.set_title(("Second Plot"))

plt.show()
- number of columns that is 1,
- figurenumber is the identification of the plot

# %%
import matplotlib.pyplot as plt

figure= plt.figure()
figure.suptitle("Subplot Graph")

axis1 = figure.add_subplot(1,2,1)    # could be (121)
axis1.plot([1,2,3],[1,2,3])
axis1.set_title("First Plot")

axis2 = figure.add_subplot(1,2,2)    # could be (122)
axis2.plot([1,2,3],[3,2,1])
axis2.set_title(("Second Plot"))

plt.show()

# %%
# new style method 1; unpack the axes
fig, ((ax1, ax2), (ax3, ax4)) = plt.subplots(2, 2, sharex=True, sharey=True)
ax1.plot(x)

# %% [markdown]
# #### Method 2 - NewStyle - [0,0]

# %%
# new style method 2; use an axes array
fig, axs = plt.subplots(2, 2, sharex=True, sharey=True)
axs[0, 0].plot(x)

plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

x= np.arange(0,2*np.pi)
fig,a =  plt.subplots(2,2)

a[0][0].plot(x,x*x)                     # this works as well:    a[0,0].plot(x,x*x)
a[0][0].set_title('square')             # this worlks as well:   a[0,0].set_title('square')

a[0][1].plot(x,np.sqrt(x))
a[0][1].set_title('square root')

a[1][0].plot(x,np.exp(x))
a[1][0].set_title('exp')

a[1][1].plot(x,np.log10(x))
a[1][1].set_title('log')

plt.show()
# Out:
# C:\Users\delchain_default\anaconda3\lib\site-packages\ipykernel_launcher.py:16: RuntimeWarning: divide by zero encountered in log10
#   app.launch_new_instance()

# %% [markdown]
# ### Save a Plot Figure

# %%
The function savefig(“FilepPath/File Name.png” ) will allow you to save the plotted figure. 
You can also define the path and file format before saving to the computer.  
The png, pdf, ps, eps and svg are the various file formats you can save.

# %%
import matplotlib.pyplot as plt
import numpy as np

x= np.arange(0,2*np.pi,0.02)
y=np.sin(x)

plt.plot(x,y)
plt.text(1.5,1,"Sin(90)=1")
plt.title("Add the text inside Figure")
plt.show()

plt.savefig("TextFigurePlot.jpeg")

# %% [markdown]
# ## Object Oriented Interface

# %% [markdown]
# A Figure in matplotlib is divided into two different objects.
#
# * Figure object : A Figure object can contain one or more axes objects
#
# * Axes object : One axes represents one plot inside figure

# %%
add_subplot(num_rows, num_cols, subplot_location) 
- creates a grid of of subplots of size (num_rows x num_cols) 
- returns an axes object for the subplot at subplot_location. 

The subplots are numbered in following way:
- First subplot is at (first row, first column) location. 
- Start from this position and continue numbering till the last column of the first row
- Start from the left most position on the second row and continue numbering

Ex: The 3rd subplot in a grid of 2x2 subplots is at location = (2nd row, 1st column)
So add_subplot(1, 1, 1) returns an axes object at 1st location in a 1x1 grid of subplots. 
In other words, only one plot is generated inside the figure.

# %%
import matplotlib.pyplot as plt

fig = plt.figure()

# Generate a grid of 2x2 subplots and get
# axes object for 1st location
ax1 = fig.add_subplot(2,2,1)
ax1.set_title('First Location')

# Get the axes object for subplot at 2nd 
# location
ax2 = fig.add_subplot(2,2,2)
ax2.set_title('Second Location')

# Get the axes object for subplot at 3rd 
# location
ax3 = fig.add_subplot(2,2,3)
ax3.set_xlabel('Third Location')

# Get the axes object for subplot at 4th 
# location
ax4 = fig.add_subplot(2,2,4)
ax4.set_xlabel('Fourth Location')

# Display
plt.show()

# %% [markdown]
# ### Multiple Graphs in the Same Plot

# %%
import matplotlib.pyplot as plt

# Function to get the square of each element in the list
def list_square(a_list):
    return [element**2 for element in a_list]

# Multiple plot : Plot y = x and z = x^2 in the same subplot window
fig2 = plt.figure()

x = [1, 2, 3, 4, 5]
y = x
z = list_square(x)

ax2 = fig2.add_subplot(1,1,1)     # Get the axes instance

# Plot y vs x as well as z vs x. label will be used by ax.legend() method to generate a legend automatically
ax2.plot(x, y, label='y')
ax2.plot(x, z, label='z')
ax2.set_xlabel("X------>")

ax2.legend()                       # Generate legend
ax2.set_title('Two plots one axes')

plt.show()

# %% [markdown]
# ### Two plots in a figure

# %%
import matplotlib.pyplot as plt
import numpy as np
import math
x = np.arange(0, math.pi*2, 0.05)
y = np.sin(x)

fig=plt.figure()

axes1 = fig.add_axes([0.1, 0.1, 0.8, 0.8])           # main axes
axes1.plot(x, y, 'b')
axes1.set_title('sine')

axes2 = fig.add_axes([0.55, 0.55, 0.3, 0.3])         # insert axes - the numbers are the fractions of the main
axes2.plot(x,np.cos(x),'r')
axes2.set_title("cosine")

axes2.set_xlim(0,10)                                 # set the limits
axes2.set_ylim(-2,2)

plt.show()

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-c9e5d8432a03> in <module>
# ----> 1 ax2.set_xlim(-2,2)
#       2 ax2.set_ylim(0,6)
#
# NameError: name 'ax2' is not defined

# %% [markdown]
# ### Difference between add_axes and add_subplot

# %%
Both, add_axes and add_subplot add an axes to a figure. 
They both return a (subclass of a) matplotlib.axes.Axes object.

However, the mechanism which is used to add the axes differs substantially.

    add_axes
    The calling signature of add_axes is add_axes(rect), 
     - where rect is a list [x0, y0, width, height] 
     - denoting the lower left point of the new axes in figure coodinates (x0,y0) and its width and height. 
     - So the axes is positionned in absolute coordinates on the canvas. 

        fig = plt.figure()
        ax = fig.add_axes([0,0,1,1])
        places a figure in the canvas that is exactly as large as the canvas itself.

    add_subplot
    The calling signature of add_subplot does not directly provide the option to place the axes at a predefined position. 
    It rather allows to specify where the axes should be situated according to a subplot grid. 
    The usual and easiest way to specify this position is the 3 integer notation,

        fig = plt.figure()
        ax = fig.add_subplot(231)

    In this example a new axes is created at the first position (1) on a grid of 2 rows and 3 columns. 
    To produce only a single axes, add_subplot(111) would be used (First plot on a 1 by 1 subplot grid).
    (In newer matplotlib versions, add_subplot()` without any arguments is possible as well.)

    
Which one to use?
    The advantage add_subplot is that matplotlib takes care of the exact positioning. 
    By default add_subplot(111) would produce an axes positioned at [0.125,0.11,0.775,0.77] or similar, 
    This leaves enough space around the axes for the title and the (tick)labels. 
    
    However, this position may also change depending on other elements in the plot, titles set, etc. 
    It can also be adjusted using pyplot.subplots_adjust(...) or pyplot.tight_layout().
    In most cases, add_subplot would be the prefered method to create axes for plots on a canvas. 
    
    Only in cases where exact positioning matters, add_axes might be useful.

# %% [markdown]
# ## Figure Parameters

# %%
.figure()

- figsize      2 -tuple of floats - default: [6.4, 4.8]
               Figure dimension (width, height) in inches.

- dpi          float, default: 100.0
               Dots per inch.

- facecolor    default: 'white'
               The figure patch facecolor.

- edgecolor    default: 'white'
               The figure patch edge color.

- linewidth    float
               The linewidth of the frame (i.e. the edge linewidth of the figure patch).

- frameon      bool, default:  True
               If False, suppress drawing the figure background patch.

- subplotpars  SubplotParams
               If not given, the default subplot parameters rcParams["figure.subplot.*"] are used.

- tight_layout bool or dict, default: False
               If False use subplotpars. 
               If True adjust subplot parameters using tight_layout with default padding.        

- constrained_layout bool , default: False
               If True use constrained layout to adjust positioning of plot elements. 
               Like tight_layout, but designed to be more flexible. 
               See Constrained Layout Guide for examples. (Note: does not work with subplot() or subplot2grid()

# %% [markdown]
# ## Boxplot

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

data = [[1,2,5,1,3,4], [5,7,2,2,1.5,5], [7,2,5]]

plt.figure()
plt.boxplot(data)


plt.tight_layout()
plt.ylim(0,9)

# %% [markdown]
# ## Logscale

# %%
import matplotlib.pyplot as plt


figure= plt.figure(figsize=(10, 4), dpi=72)
       
x = np.linspace(0, 5, 11)
y = x ** 2
z = np.exp(x)

axis1 = figure.add_subplot(1,2,1)  
axis1.plot(x,y)
axis1.plot(x,z)
axis1.set_title("Normal Scale")

axis2 = figure.add_subplot(1,2,2)    
axis2.plot(x,y)
axis2.plot(x,z)
axis2.set_yscale('log')
axis2.set_title(("Log Scale (y)"))

plt.show()

# %% [markdown]
# ## Ticklabels

# %%
import matplotlib.pyplot as plt


figure= plt.figure(figsize=(10, 4), dpi=72)
       
x = np.linspace(0, 5, 11)
y = x ** 2
z = np.exp(x)

axis1 = figure.add_subplot(111)  
axis1.plot(x,y)
axis1.plot(x,z)

axis1.tick_params(labelsize=20,direction='out',pad=10)
axis1.set_xticklabels(['','','α', 'β', 'γ', 'δ', 'ε'])
# Out:
# [Text(0, 0, ''),
#  Text(0, 0, ''),
#  Text(0, 0, 'α'),
#  Text(0, 0, 'β'),
#  Text(0, 0, 'γ'),
#  Text(0, 0, 'δ'),
#  Text(0, 0, 'ε')]

# %% [markdown]
# ## Change axis, remove axis

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

xx = np.linspace(-0.75, 1., 100)
n = np.array([0,1,2,3,4,5])

fig1, axis1 = plt.subplots()
axis1.plot(xx, xx**3)

axis1.spines['right'].set_color('none')
axis1.spines['top'].set_color('none')
axis1.xaxis.set_ticks_position('bottom')
axis1.spines['bottom'].set_position(('data',0))
axis1.yaxis.set_ticks_position('left')
axis1.spines['left'].set_position(('data',0))

# %% [markdown]
# ## Double Axis

# %%
import matplotlib.pyplot as plt
import numpy as np

x = np.linspace(0, 5, 11)
y = x ** 2
z = x **3


fig, ax1 = plt.subplots(1,1)

ax1.plot(x, y, 'b')

ax1.set_ylabel("area (m^2)", fontsize=20, color='blue')
for label in ax1.get_yticklabels():
    label.set_color("blue")
    
ax2 = ax1.twinx()
ax2.plot(x, z, 'r')

ax2.set_ylabel("volume (m^3)", fontsize=20, color="red")
for label in ax2.get_yticklabels():
    label.set_color("red")

# %% [markdown]
# ## Text Annotation

# %%
xx = np.linspace(-0.75, 1, 100)
y = xx ** 2
z = xx **3

fig, ax1 = plt.subplots(1,1)

ax1.plot(xx, y)
ax1.plot(xx, z)

ax1.set_xlim(-0.75,1)

ax1.text(0.12, 0.2, "y=x^2", fontsize=15, color="blue")
ax1.text(0.6, 0.08, "y=x^3", fontsize=15, color="green")
# Out:
# Text(0.6, 0.08, 'y=x^3')

# %% [markdown]
# ## Custom Layout

# %%
fig = plt.figure()

ax1 = plt.subplot2grid((3,3), (0,0), colspan=3)
ax2 = plt.subplot2grid((3,3), (1,0), colspan=2)
ax3 = plt.subplot2grid((3,3), (1,2), rowspan=2)
ax4 = plt.subplot2grid((3,3), (2,0))
ax5 = plt.subplot2grid((3,3), (2,1))

fig.tight_layout()
