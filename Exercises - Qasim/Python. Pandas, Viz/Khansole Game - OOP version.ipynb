# %%
import random

correct_answer = 0
goal = 3

while correct_answer < goal:
   
    number1 = random.randint(1,99)
    number2 = random.randint(1,99)
    truth = number1 + number2

    print('-'*100)
    print("What is {} + {}?".format(number1, number2))
    answer = int(input("Your answer: "))

          
    if int(answer) == int(truth):
        correct_answer += 1
        if correct_answer == 1:
            print("Correct! You've gotten {} correct answer in a row".format(correct_answer))
        else:
            print("Correct! You've gotten {} correct answers in a row".format(correct_answer))
    else:
        correct_answer = 0
        print("Incorrect. The expected answer is {}".format(truth))
        
print("Congratulations! You mastered addition.")
# Out:
# ----------------------------------------------------------------------------------------------------
# What is 75 + 96?
# Your answer: 171
# Correct! You've gotten 1 correct answer in a row
# ----------------------------------------------------------------------------------------------------
# What is 90 + 15?
# Your answer: 105
# Correct! You've gotten 2 correct answers in a row
# ----------------------------------------------------------------------------------------------------
# What is 12 + 47?
# Your answer: 59
# Correct! You've gotten 3 correct answers in a row
# Congratulations! You mastered addition.

# %%
import random

class player():
    
    def __init__(self, answers):
        self.answers = answers
        
    def has_reached_goal(self):
        return (self.answers.correct) == 3
    
    
class answers():        
    
    def __init__(self, correct):
        self.correct = correct
    
    def __str__(self):
        return "Correct! You've gotten {} correct in a row".format(self.correct)
    
    def player_answer(self):
        return int(input("Your answer: "))
    
    
            
class question():
    
    def __init__(self):
        self.number1 = number1
        self.number2 = number2

    def ask_question(self):
        self.number1 = random.randint(1,99)
        self.number2 = random.randint(1,99)
        return "What is {} + {}?".format(self.number1, self.number2)
    
    def true_answer(self):
        truth = self.number1 + self.number2
        
#########################################################################################

total_rounds = 0
correct_answer = 0


while player.has_reached_goal:
    total_rounds += 1
    
    print('-'*100)
   # New_Question = question.ask_question()
   # New_Answer = answers.player_answer()
        
    New_Question = question.ask_question()
   # New_Answer = answers.player_answer()    
        
    print(New_Question)
    print(New_Answer)

    if int(answers.player_answer) == int(question.true_answer):
        correct_answer += 1
        print(answers)
        print(New_Question)
        print(New_Asnwer)
            
    else:
        correct_answer = 0
