# %% [markdown]
# # Building and Testing Recommender Systems With Surprise

# %% [markdown]
# Surprise is a Python scikit building and analyzing recommender systems that deal with explicit rating data.
#
# <http://surpriselib.com/>

# %%
import pandas as pd
import matplotlib as plt
import seaborn as sns

# %%
movies = pd.read_csv(r'C:\Users\delchain_default\Documents\GitHub\Python-Notes\Machine Learning\Recommender System (Advanced)\Movie_data.csv')

movies.head()
# Out:
#    Unnamed: 0  user_id  item_id  rating  timestamp             title
# 0           0        0       50       5  881250949  Star Wars (1977)
# 1           1      290       50       5  880473582  Star Wars (1977)
# 2           2       79       50       4  891271545  Star Wars (1977)
# 3           3        2       50       5  888552084  Star Wars (1977)
# 4           4        8       50       5  879362124  Star Wars (1977)

# %%
users = movies.groupby('user_id')['rating'].count().reset_index().sort_values('rating', ascending=False)
users
# Out:
#      user_id  rating
# 405      405     737
# 655      655     685
# 13        13     636
# 450      450     540
# 276      276     518
# ..       ...     ...
# 571      571      20
# 19        19      20
# 888      888      20
# 895      895      20
# 0          0       3
#
# [944 rows x 2 columns]

# %% [markdown]
# Most of the users gave less than 5 ratings, and very few users gave many ratings, although the most productive user have given 13,602 ratings.
#
# I'm sure you have noticed that the above two charts share the same distribution. The number of ratings per movie and the bnumber of ratings per user decay exponentially.
#
# To reduce the dimensionality of the dataset, we will filter out rarely rated movies and rarely rating users.

# %%
min_movie_ratings = 50
filter_movies = movies['title'].value_counts() > min_movie_ratings
filter_movies = filter_movies[filter_movies].index.tolist()

min_user_ratings = 50
filter_users = movies['user_id'].value_counts() > min_user_ratings
filter_users = filter_users[filter_users].index.tolist()

df = movies[(movies['title'].isin(filter_movies)) & (movies['user_id'].isin(filter_users))]
print('The original data frame shape:\t{}'.format(movies.shape))
print('The new data frame shape:\t{}'.format(df.shape))
# Out:
# The original data frame shape:	(100003, 6)
# The new data frame shape:	(73134, 6)

# %%
df['title'].nunique()
# Out:
# 596

# %%
df
# Out:
#        Unnamed: 0  user_id  item_id  rating  timestamp               title
# 1               1      290       50       5  880473582    Star Wars (1977)
# 2               2       79       50       4  891271545    Star Wars (1977)
# 3               3        2       50       5  888552084    Star Wars (1977)
# 4               4        8       50       5  879362124    Star Wars (1977)
# 5               5      274       50       5  878944679    Star Wars (1977)
# ...           ...      ...      ...     ...        ...                 ...
# 97645       97645      493      881       1  884130009  Money Talks (1997)
# 97647       97647      697      881       2  882621523  Money Talks (1997)
# 97649       97649      629      881       3  880116023  Money Talks (1997)
# 97652       97652      889      881       3  880176717  Money Talks (1997)
# 97653       97653      880      881       4  892958401  Money Talks (1997)
#
# [73134 rows x 6 columns]

# %% [markdown]
# ## Surprise

# %% [markdown]
# To load a data set from the above pandas data frame, we will use the load_from_df() method, we will also need a Reader object, and the rating_scale parameter must be specified. The data frame must have three columns, corresponding to the user ids, the item ids, and the ratings in this order. Each row thus corresponds to a given rating.

# %%
from surprise import Reader
from surprise import Dataset

from surprise.model_selection import cross_validate
from surprise import NormalPredictor
from surprise import KNNBasic
from surprise import KNNWithMeans
from surprise import KNNWithZScore
from surprise import KNNBaseline
from surprise import SVD
from surprise import BaselineOnly
from surprise import SVDpp
from surprise import NMF
from surprise import SlopeOne
from surprise import CoClustering

from surprise.accuracy import rmse
from surprise import accuracy
from surprise.model_selection import train_test_split

# %%
reader = Reader(rating_scale=(1, 5))
data = Dataset.load_from_df(df[['user_id', 'title', 'rating']], reader)

# %% [markdown]
# The Reader class is used to parse a file containing ratings.
#
# Such a file is assumed to specify only one rating per line, and each line needs to respect the following structure:

# %%
benchmark = []

# Iterate over all algorithms
for algorithm in [SVD(), SVDpp(),SlopeOne(), NormalPredictor(), KNNBaseline(), KNNBasic(), KNNWithMeans(), KNNWithZScore(), BaselineOnly(), CoClustering()]:   # NMF()
    # Perform cross validation
    results = cross_validate(algorithm, data, measures=['RMSE'], cv=3, verbose=False)
    
    # Get results & append algorithm name
    tmp = pd.DataFrame.from_dict(results).mean(axis=0)
    tmp = tmp.append(pd.Series([str(algorithm).split(' ')[0].split('.')[-1]], index=['Algorithm']))
    benchmark.append(tmp)
# Out:
# Estimating biases using als...
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Estimating biases using als...
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Estimating biases using als...
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Estimating biases using als...
# Estimating biases using als...
# Estimating biases using als...

# %%
surprise_results = pd.DataFrame(benchmark).set_index('Algorithm').sort_values('test_rmse')
surprise_results
# Out:
#                  test_rmse   fit_time  test_time
# Algorithm
# SVDpp             0.904197  51.608334   2.036390
# KNNBaseline       0.909188   0.194483   3.200658
# SVD               0.919603   1.969649   0.130978
# SlopeOne          0.920265   0.161577   1.781889
# KNNWithMeans      0.921643   0.160902   2.651117
# KNNWithZScore     0.922562   0.191471   2.867672
# BaselineOnly      0.922689   0.060172   0.095410
# CoClustering      0.930808   0.828451   0.112698
# KNNBasic          0.946183   0.152260   2.464787
# NormalPredictor   1.456741   0.052526   0.128323

# %% [markdown]
# ## Train and Predict

# %% [markdown]
# SVDpp produces the best results, however it it very time consuming. lets train and predict using KNNBaseline

# %%
print('Using KNNBaseline')
bsl_options = {'method': 'als',
               'n_epochs': 5,
               'reg_u': 12,
               'reg_i': 5
               }
algo = KNNBaseline()
cross_validate(algo, data, measures=['RMSE'], cv=3, verbose=False)
# Out:
# Using KNNBaseline
# Estimating biases using als...
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Estimating biases using als...
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Estimating biases using als...
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# {'test_rmse': array([0.9062596 , 0.90635535, 0.91391631]),
#  'fit_time': (0.21741890907287598, 0.19944000244140625, 0.1965010166168213),
#  'test_time': (3.2124080657958984, 3.241358518600464, 3.121652364730835)}

# %% [markdown]
# We use the train_test_split() to sample a trainset and a testset with given sizes, and use the accuracy metric of rmse. We’ll then use the fit() method which will train the algorithm on the trainset, and the test() method which will return the predictions made from the testset.

# %%
trainset, testset = train_test_split(data, test_size=0.25)
algo = KNNBaseline()

predictions = algo.fit(trainset).test(testset)
accuracy.rmse(predictions)
# Out:
# Estimating biases using als...
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# RMSE: 0.8962
# 0.8961858518195142

# %% [markdown]
# To inspect our predictions in details, we are going to build a pandas data frame with all the predictions. The following code were largely taken from this notebook.

# %%
trainset = algo.trainset
print(algo.__class__.__name__)
# Out:
# KNNBaseline

# %% [markdown]
# To inspect our predictions in details, we are going to build a pandas data frame with all the predictions.

# %%
def get_Iu(user_id):
#     """ return the number of items rated by given user args: 
#       user_id: the id of the user 
#       Item_User : the number of items rated by the user
#     """
    try:
        return len(trainset.ur[trainset.to_inner_uid(user_id)])
    except ValueError: # user was not part of the trainset
        return 0
    
def get_Ui(item_id):
#     """ return number of users that have rated given item :
#       item_id: the title of the movie
#       User_Item: the number of users that have rated the item.
#     """
    try: 
        return len(trainset.ir[trainset.to_inner_iid(item_id)])
    except ValueError:
        return 0
    
df1 = pd.DataFrame(predictions, columns=['user_id', 'item_id', 'real', 'est', 'details'])
df1['Item_USer'] = df1.user_id.apply(get_Iu)
df1['User_Item'] = df1.item_id.apply(get_Ui)
df1['err'] = abs(df1.est - df1.real)

# %%
df1.head()
# Out:
#    user_id                             item_id  real       est  \
# 0      504  Four Weddings and a Funeral (1994)   3.0  3.890772
# 1      361                   Birds, The (1963)   3.0  3.791958
# 2      650                   Highlander (1986)   3.0  2.998583
# 3      234                       Batman (1989)   1.0  3.007702
# 4      383                  Bob Roberts (1992)   4.0  4.331532
#
#                                      details  Item_USer  User_Item       err
# 0  {'actual_k': 40, 'was_impossible': False}        143        182  0.890772
# 1  {'actual_k': 40, 'was_impossible': False}         86        117  0.791958
# 2  {'actual_k': 40, 'was_impossible': False}        184        111  0.001417
# 3  {'actual_k': 40, 'was_impossible': False}        252        146  2.007702
# 4  {'actual_k': 40, 'was_impossible': False}         53         63  0.331532

# %%
# what is 'details' ? 
# what i am wondering: if i create a user with a couple of movies ratings, how do i issue recommendations for this user?
# we used cross validation in order to validate
# how can we optimize the knn parameters? is there a GridSearch method available to improve the fit?

# %%
best_predictions = df1.sort_values(by='err')[:20]
worst_predictions = df1.sort_values(by='err')[-20:]

# %%
df1.shape
# Out:
# (18284, 8)

# %%
best_predictions
# Out:
#        user_id                                            item_id  real  est  \
# 17487      130                                  Braveheart (1995)   5.0  5.0
# 7597       457                         Wrong Trousers, The (1993)   5.0  5.0
# 2094       507                                     Titanic (1997)   5.0  5.0
# 7480       330                            Schindler's List (1993)   5.0  5.0
# 3257        16                         Usual Suspects, The (1995)   5.0  5.0
# 8539       907                           Great Escape, The (1963)   5.0  5.0
# 14338      152                                  Braveheart (1995)   5.0  5.0
# 7433       821                                  Casablanca (1942)   5.0  5.0
# 3355       118                              Apocalypse Now (1979)   5.0  5.0
# 11367      532                            Schindler's List (1993)   5.0  5.0
# 12763      118  Dr. Strangelove or: How I Learned to Stop Worr...   5.0  5.0
# 5461       507                          As Good As It Gets (1997)   5.0  5.0
# 14138      507                                   Apt Pupil (1998)   5.0  5.0
# 13919      686                   Shawshank Redemption, The (1994)   5.0  5.0
# 13535       16                   Silence of the Lambs, The (1991)   5.0  5.0
# 569        907                            Schindler's List (1993)   5.0  5.0
# 3863       532                           Good Will Hunting (1997)   5.0  5.0
# 15868      332                     Raiders of the Lost Ark (1981)   5.0  5.0
# 4728       233                            Schindler's List (1993)   5.0  5.0
# 11074      330                   Shawshank Redemption, The (1994)   5.0  5.0
#
#                                          details  Item_USer  User_Item  err
# 17487  {'actual_k': 40, 'was_impossible': False}        203        210  0.0
# 7597   {'actual_k': 40, 'was_impossible': False}        186         77  0.0
# 2094   {'actual_k': 40, 'was_impossible': False}         37        158  0.0
# 7480   {'actual_k': 40, 'was_impossible': False}        103        196  0.0
# 3257   {'actual_k': 40, 'was_impossible': False}         88        180  0.0
# 8539   {'actual_k': 40, 'was_impossible': False}        100         87  0.0
# 14338  {'actual_k': 40, 'was_impossible': False}         74        210  0.0
# 7433   {'actual_k': 40, 'was_impossible': False}         43        164  0.0
# 3355   {'actual_k': 40, 'was_impossible': False}         40        150  0.0
# 11367  {'actual_k': 40, 'was_impossible': False}        135        196  0.0
# 12763  {'actual_k': 40, 'was_impossible': False}         40        137  0.0
# 5461   {'actual_k': 40, 'was_impossible': False}         37         59  0.0
# 14138  {'actual_k': 40, 'was_impossible': False}         37         76  0.0
# 13919  {'actual_k': 40, 'was_impossible': False}         49        191  0.0
# 13535  {'actual_k': 40, 'was_impossible': False}         88        258  0.0
# 569    {'actual_k': 40, 'was_impossible': False}        100        196  0.0
# 3863   {'actual_k': 40, 'was_impossible': False}        135         93  0.0
# 15868  {'actual_k': 40, 'was_impossible': False}        115        275  0.0
# 4728   {'actual_k': 40, 'was_impossible': False}         71        196  0.0
# 11074  {'actual_k': 40, 'was_impossible': False}        103        191  0.0

# %%
worst_predictions
# Out:
#        user_id                                 item_id  real       est  \
# 14333      207                   Vegas Vacation (1997)   5.0  1.929244
# 11690      246                     Pulp Fiction (1994)   1.0  4.074338
# 4748       867                Leaving Las Vegas (1995)   1.0  4.083843
# 978        887                    Private Parts (1997)   1.0  4.084153
# 6736       189                       Local Hero (1983)   1.0  4.086916
# 1628       562  One Flew Over the Cuckoo's Nest (1975)   1.0  4.111777
# 17369      314                     Pulp Fiction (1994)   1.0  4.116691
# 9277       588                    Groundhog Day (1993)   1.0  4.164159
# 8103       559                       Braveheart (1995)   1.0  4.165262
# 7307       145                         Face/Off (1997)   1.0  4.165268
# 11264       38                     Men in Black (1997)   1.0  4.206455
# 4827       771        Silence of the Lambs, The (1991)   1.0  4.207949
# 10981      887                     Little Women (1994)   1.0  4.264528
# 3795       253                      Raging Bull (1980)   1.0  4.272511
# 16323      712               Three Colors: Blue (1993)   1.0  4.350281
# 7771       642                   Reservoir Dogs (1992)   1.0  4.404973
# 3615       416          Remains of the Day, The (1993)   1.0  4.519510
# 13254      780        Silence of the Lambs, The (1991)   1.0  4.565057
# 13395      239                          Henry V (1989)   1.0  4.565860
# 730        405                           Jaws 2 (1978)   5.0  1.407357
#
#                                          details  Item_USer  User_Item  \
# 14333  {'actual_k': 40, 'was_impossible': False}        145         43
# 11690  {'actual_k': 40, 'was_impossible': False}        121        278
# 4748   {'actual_k': 40, 'was_impossible': False}         65        167
# 978    {'actual_k': 40, 'was_impossible': False}        100         64
# 6736   {'actual_k': 40, 'was_impossible': False}        120         47
# 1628   {'actual_k': 40, 'was_impossible': False}         50        188
# 17369  {'actual_k': 40, 'was_impossible': False}        124        278
# 9277   {'actual_k': 40, 'was_impossible': False}        143        207
# 8103   {'actual_k': 40, 'was_impossible': False}         52        210
# 7307   {'actual_k': 40, 'was_impossible': False}        174        112
# 11264  {'actual_k': 40, 'was_impossible': False}         71        165
# 4827   {'actual_k': 40, 'was_impossible': False}         48        258
# 10981  {'actual_k': 40, 'was_impossible': False}        100         83
# 3795   {'actual_k': 40, 'was_impossible': False}         73         74
# 16323  {'actual_k': 40, 'was_impossible': False}         84         42
# 7771   {'actual_k': 40, 'was_impossible': False}        150        109
# 3615   {'actual_k': 40, 'was_impossible': False}        281        102
# 13254  {'actual_k': 40, 'was_impossible': False}         41        258
# 13395  {'actual_k': 40, 'was_impossible': False}         98         93
# 730    {'actual_k': 40, 'was_impossible': False}        253         52
#
#             err
# 14333  3.070756
# 11690  3.074338
# 4748   3.083843
# 978    3.084153
# 6736   3.086916
# 1628   3.111777
# 17369  3.116691
# 9277   3.164159
# 8103   3.165262
# 7307   3.165268
# 11264  3.206455
# 4827   3.207949
# 10981  3.264528
# 3795   3.272511
# 16323  3.350281
# 7771   3.404973
# 3615   3.519510
# 13254  3.565057
# 13395  3.565860
# 730    3.592643
